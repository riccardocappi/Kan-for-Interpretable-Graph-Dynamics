# %%
import networkx as nx
from torch_geometric.utils import from_networkx
import torch
from utils.utils import create_datasets, load_config, pre_processing
import numpy as np

# %%
config = load_config(config_path='./configs/config_kuramoto.yml')

G = nx.complete_graph(10)
# G = nx.grid_2d_graph(7, 10)
train_data, t_train, valid_data, t_valid , test_data, t_test = create_datasets(config=config, graph=G)

# %%
train_data = pre_processing(train_data)
valid_data = pre_processing(valid_data)
test_data = pre_processing(test_data)

# %%
from models.KanGDyn import KanGDyn
from models.NetWrapper import NetWrapper

# %%
edge_index = from_networkx(G).edge_index

model_config = {
    'h_hidden_layers':[2, 1],
    'g_hidden_layers':[2,1,1],
    'grid_range':[-3, 3],
    'grid_size': 7,
    'model_path':'./saved_models/higher-order-kuramoto',
    'device':'cpu',
    'store_acts':True
}

model = NetWrapper(KanGDyn, model_config, edge_index, update_grid=False)

criterion = torch.nn.MSELoss()
lr = 0.001
mu_1 = 1.
mu_2 = 1.
lmbd = 0.0001
epochs = 300
opt = torch.optim.Adam(model.parameters(), lr=lr)

# %%
from train_and_eval import fit

# %%
_ = fit(
    model,
    train_data,
    t_train,
    valid_data,
    t_valid,
    test_data,
    t_test,
    epochs=epochs,
    patience=100,
    lr=lr,
    lmbd=lmbd,
    mu_1=mu_1,
    mu_2=mu_2,
    criterion=criterion,
    use_orig_reg=True,
    save_updates=True
)
# Out:
# Epoch: 0 	 Training loss: 0.07325 	 Val Loss: 0.05443 	 Tot Loss: 0.07358
# Epoch: 10 	 Training loss: 0.06892 	 Val Loss: 0.05110 	 Tot Loss: 0.06925
# Epoch: 20 	 Training loss: 0.06490 	 Val Loss: 0.04803 	 Tot Loss: 0.06523
# Epoch: 30 	 Training loss: 0.06117 	 Val Loss: 0.04521 	 Tot Loss: 0.06149
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 _ = fit(
#       2     model,
#       3     train_data,
#       4     t_train,
#       5     valid_data,
#       6     t_valid,
#       7     test_data,
#       8     t_test,
#       9     epochs=epochs,
#      10     patience=100,
#      11     lr=lr,
#      12     lmbd=lmbd,
#      13     mu_1=mu_1,
#      14     mu_2=mu_2,
#      15     criterion=criterion,
#      16     use_orig_reg=True,
#      17     save_updates=True
#      18 )
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\train_and_eval.py:99, in fit(model, train_data, t_train, valid_data, t_valid, test_data, t_test, seed, epochs, patience, lr, lmbd, log, mu_1, mu_2, log_file_name, criterion, opt, use_orig_reg, save_updates)
#      97 running_entropy = 0.
#      98 if opt == 'Adam':
# ---> 99     _ = training()
#     100 else:
#     101     optimizer.step(training)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\train_and_eval.py:85, in fit.<locals>.training()
#      83 running_l1 = running_l1 + l1.item()
#      84 running_entropy = running_entropy + entropy.item()
# ---> 85 loss.backward()
#      86 if opt == 'Adam':
#      87     optimizer.step()
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\autograd\function.py:307, in BackwardCFunction.apply(self, *args)
#     301     raise RuntimeError(
#     302         "Implementing both 'backward' and 'vjp' for a custom "
#     303         "Function is not allowed. You should only implement one "
#     304         "of them."
#     305     )
#     306 user_fn = vjp_fn if vjp_fn is not Function.vjp else backward_fn
# --> 307 return user_fn(self, *args)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torchdiffeq\_impl\adjoint.py:134, in OdeintAdjointMethod.backward(ctx, *grad_y)
#     131     time_vjps[i] = dLd_cur_t
#     133 # Run the augmented system backwards in time.
# --> 134 aug_state = odeint(
#     135     augmented_dynamics, tuple(aug_state),
#     136     t[i - 1:i + 1].flip(0),
#     137     rtol=adjoint_rtol, atol=adjoint_atol, method=adjoint_method, options=adjoint_options
#     138 )
#     139 aug_state = [a[1] for a in aug_state]  # extract just the t[i - 1] value
#     140 aug_state[1] = y[i - 1]  # update to use our forward-pass estimate of the state
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torchdiffeq\_impl\odeint.py:80, in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      77 solver = SOLVERS[method](func=func, y0=y0, rtol=rtol, atol=atol, **options)
#      79 if event_fn is None:
# ---> 80     solution = solver.integrate(t)
#      81 else:
#      82     event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torchdiffeq\_impl\solvers.py:34, in AdaptiveStepsizeODESolver.integrate(self, t)
#      32 self._before_integrate(t)
#      33 for i in range(1, len(t)):
# ---> 34     solution[i] = self._advance(t[i])
#      35 return solution
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torchdiffeq\_impl\rk_common.py:246, in RKAdaptiveStepsizeODESolver._advance(self, next_t)
#     244 while next_t > self.rk_state.t1:
#     245     assert n_steps < self.max_num_steps, 'max_num_steps exceeded ({}>={})'.format(n_steps, self.max_num_steps)
# --> 246     self.rk_state = self._adaptive_step(self.rk_state)
#     247     n_steps += 1
#     248 return _interp_evaluate(self.rk_state.interp_coeff, self.rk_state.t0, self.rk_state.t1, next_t)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torchdiffeq\_impl\rk_common.py:311, in RKAdaptiveStepsizeODESolver._adaptive_step(self, rk_state)
#     306         dt = t1 - t0
#     308 # Must be arranged as doing all the step_t handling, then all the jump_t handling, in case we
#     309 # trigger both. (i.e. interleaving them would be wrong.)
# --> 311 y1, f1, y1_error, k = _runge_kutta_step(self.func, y0, f0, t0, dt, t1, tableau=self.tableau)
#     312 # dtypes:
#     313 # y1.dtype == self.y0.dtype
#     314 # f1.dtype == self.y0.dtype
#    (...)
#     319 #                     Error Ratio                      #
#     320 ########################################################
#     321 error_ratio = _compute_error_ratio(y1_error, self.rtol, self.atol, y0, y1, self.norm)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torchdiffeq\_impl\rk_common.py:78, in _runge_kutta_step(func, y0, f0, t0, dt, t1, tableau)
#      76         perturb = Perturb.NONE
#      77     yi = y0 + torch.sum(k[..., :i + 1] * (beta_i * dt), dim=-1).view_as(f0)
# ---> 78     f = func(ti, yi, perturb=perturb)
#      79     k = _UncheckedAssign.apply(k, f, (..., i + 1))
#      81 if not (tableau.c_sol[-1] == 0 and (tableau.c_sol[:-1] == tableau.beta[-1]).all()):
#      82     # This property (true for Dormand-Prince) lets us save a few FLOPs.
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torchdiffeq\_impl\misc.py:197, in _PerturbFunc.forward(self, t, y, perturb)
#     194 else:
#     195     # Do nothing.
#     196     pass
# --> 197 return self.base_func(t, y)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torchdiffeq\_impl\misc.py:165, in _ReverseFunc.forward(self, t, y)
#     164 def forward(self, t, y):
# --> 165     return self.mul * self.base_func(-t, y)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torchdiffeq\_impl\misc.py:144, in _TupleFunc.forward(self, t, y)
#     143 def forward(self, t, y):
# --> 144     f = self.base_func(t, _flat_to_shape(y, (), self.shapes))
#     145     return torch.cat([f_.reshape(-1) for f_ in f])
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torchdiffeq\_impl\adjoint.py:87, in OdeintAdjointMethod.backward.<locals>.augmented_dynamics(t, y_aug)
#      82 y = y.detach().requires_grad_(True)
#      84 # If using an adaptive solver we don't want to waste time resolving dL/dt unless we need it (which
#      85 # doesn't necessarily even exist if there is piecewise structure in time), so turning off gradients
#      86 # wrt t here means we won't compute that if we don't need it.
# ---> 87 func_eval = func(t if t_requires_grad else t_, y)
#      89 # Workaround for PyTorch bug #39784
#      90 _t = torch.as_strided(t, (), ())  # noqa
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torchdiffeq\_impl\misc.py:197, in _PerturbFunc.forward(self, t, y, perturb)
#     194 else:
#     195     # Do nothing.
#     196     pass
# --> 197 return self.base_func(t, y)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\models\NetWrapper.py:13, in NetWrapper.forward(self, t, x)
#      12 def forward(self, t, x):
# ---> 13     return self.model(x, self.edge_index, **self.kwargs)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\models\KanGDyn.py:68, in KanGDyn.forward(self, x, edge_index, update_grid)
#      65 def forward(self, x, edge_index, update_grid=False):
#      66     norm = self.get_norm(edge_index, x) if self.norm else torch.ones(edge_index.shape[1], device=x.device)
# ---> 68     return self.propagate(edge_index, x=x, norm=norm, update_grid=update_grid)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch_geometric\nn\conv\message_passing.py:467, in MessagePassing.propagate(self, edge_index, size, **kwargs)
#     465     if res is not None:
#     466         msg_kwargs = res[0] if isinstance(res, tuple) else res
# --> 467 out = self.message(**msg_kwargs)
#     468 for hook in self._message_forward_hooks.values():
#     469     res = hook(self, (msg_kwargs, ), out)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\models\KanGDyn.py:72, in KanGDyn.message(self, x_i, x_j, norm, update_grid)
#      71 def message(self, x_i, x_j, norm, update_grid):
# ---> 72     mes = self.g_net(torch.cat([x_j, x_i], dim=-1), update_grid=update_grid)
#      73     return norm.view(-1, 1) * mes
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\models\KAN.py:84, in KAN.forward(self, x, update_grid)
#      81     if update_grid:
#      82         layer.update_grid(x)
# ---> 84     x = layer(x, self.store_act)
#      85 return x
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\models\KanLayer.py:285, in KANLayer.forward(self, x, store_act)
#     282 x = x.reshape(-1, self.in_features)
#     284 if store_act:
# --> 285     output = self.get_activations(x) # (batch, out_features)
#     286 else:
#     287     output = self.get_activations_efficient(x) # (batch, out_features)
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\models\KanLayer.py:244, in KANLayer.get_activations(self, x)
#     241 base_act = self.base_activation(x)
#     242 base_output = base_act[:, None, :] * self.base_weight # (batch, out_features, in_features)
# --> 244 splines = self.b_splines(x) # (batch, in, coeff)
#     245 output_b_spline = torch.einsum('jik, bik -> bji', self.scaled_spline_weight, splines) # (batch, out_features, in_features)
#     247 output_layer = output_b_spline + base_output
#
# File c:\Users\ricca\OneDrive\Desktop\VS Code Projects\KAN for Interpretable Graph Dynamics\models\KanLayer.py:112, in KANLayer.b_splines(self, x)
#     110 # Each basis function is define in the range [i, i + k + 1]
#     111 for k in range(1, self.spline_order + 1):
# --> 112     bases = (
#     113         (x - grid[:, : -(k + 1)])
#     114         / (grid[:, k:-1] - grid[:, : -(k + 1)])
#     115         * bases[:, :, :-1]
#     116     ) + (
#     117         (grid[:, k + 1 :] - x)
#     118         / (grid[:, k + 1 :] - grid[:, 1:(-k)])
#     119         * bases[:, :, 1:]
#     120     )
#     122 assert bases.size() == (
#     123     x.size(0),
#     124     self.in_features,
#     125     self.grid_size + self.spline_order,
#     126 )
#     127 return bases.contiguous()
#
# KeyboardInterrupt:

# %%
best_model_state = torch.load(f'./{model.model.model_path}/best_state_dict.pth', weights_only=False)

# %%
from utils.utils import plot, save_acts, sample_from_spatio_temporal_graph

# %%
model.load_state_dict(best_model_state)

net = model.model

net.h_net.store_act = True
net.g_net.store_act = True

dummy_x, dummy_edge_index = sample_from_spatio_temporal_graph(train_data, edge_index, sample_size=32)

with torch.no_grad():
    _ = net(dummy_x, dummy_edge_index)

plot(folder_path=f'{net.h_net.model_path}/figures', layers=net.h_net.layers, show_plots=False)
plot(folder_path=f'{net.g_net.model_path}/figures', layers=net.g_net.layers, show_plots=False)

save_acts(layers=net.h_net.layers, folder_path=f'{net.h_net.model_path}/cached_acts')
save_acts(layers=net.g_net.layers, folder_path=f'{net.g_net.model_path}/cached_acts')
